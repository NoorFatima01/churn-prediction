# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c348dd77-ceed-4ce6-b169-aca1a4fa51e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c348dd77-ceed-4ce6-b169-aca1a4fa51e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("tel_churn.csv")
dataset.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0              29            29      0
# 1           1              0              56          1889      0
# 2           2              0              53           108      1
# 3           3              0              42          1840      0
# 4           4              0              70           151      1
#
#    gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            0            1               0                 0
# 1            1            0               0                 1
# 2            1            0               0                 1
# 3            1            0               0                 0
# 4            0            0               0                 1
#
#    MultipleLines_No phone service  ...  Contract_Two year  \
# 0                               1  ...                  0
# 1                               0  ...                  0
# ...

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)

# %%
# Creating x and y variables
x = dataset.drop('Churn', axis=1)
x # independent variables
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Male  Partner_Yes  \
# 0                 0              29            29            0            1
# 1                 0              56          1889            1            0
# 2                 0              53           108            1            0
# 3                 0              42          1840            1            0
# 4                 0              70           151            0            0
# ...             ...             ...           ...          ...          ...
# 7027              0              84          1990            1            1
# 7028              0             103          7362            0            1
# 7029              0              29           346            0            1
# 7030              1              74           306            1            1
# 7031              0             105          6844            1            0
#
# ...

# %%
y = dataset['Churn']
y # dependent variable
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
# Train-test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # Model creation

# %%
model_dt=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_dt.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.7981520966595593

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1045
#            1       0.66      0.45      0.54       362
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.69      0.70      1407
# weighted avg       0.78      0.80      0.78      1407

# %% [markdown]
# SMOTEENN first uses SMOTE to generate synthetic examples for the minority class to balance the dataset, and then it uses ENN to clean up the dataset by removing noisy or borderline examples from both the majority and minority classes.

# %%
sm = SMOTEENN()
X_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(X_resampled, y_resampled,test_size=0.2)

# %%
model_dt_smote=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt_smote.fit(xr_train,yr_train)
yr_predict = model_dt_smote.predict(xr_test)
model_score_r = model_dt_smote.score(xr_test, yr_test)
print(model_score_r)
print(metrics.classification_report(yr_test, yr_predict))
# Out:
# 0.9143865842894969
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90       536
#            1       0.88      0.97      0.92       597
#
#     accuracy                           0.91      1133
#    macro avg       0.92      0.91      0.91      1133
# weighted avg       0.92      0.91      0.91      1133

# %%
print(metrics.confusion_matrix(yr_test, yr_predict))
# Out:
# [[455  81]
#  [ 16 581]]

# %% [markdown]
# ##Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_rf.predict(x_test)

# %%
model_rf.score(x_test,y_test)
# Out:
# 0.7931769722814499

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      1045
#            1       0.67      0.39      0.49       362
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.66      0.68      1407
# weighted avg       0.78      0.79      0.77      1407

# %%
sm = SMOTEENN()
X_resampled1, y_resampled1 = sm.fit_resample(x,y)

# %%
xr_train1,xr_test1,yr_train1,yr_test1=train_test_split(X_resampled1, y_resampled1,test_size=0.2)

# %%
model_rf_smote=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf_smote.fit(xr_train1,yr_train1)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
yr_predict1 = model_rf_smote.predict(xr_test1)

# %%
model_score_r1 = model_rf_smote.score(xr_test1, yr_test1)

# %%
print(model_score_r1)
print(metrics.classification_report(yr_test1, yr_predict1))
# Out:
# 0.9203463203463204
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.91       571
#            1       0.88      0.97      0.93       584
#
#     accuracy                           0.92      1155
#    macro avg       0.93      0.92      0.92      1155
# weighted avg       0.92      0.92      0.92      1155

# %%
print(metrics.confusion_matrix(yr_test1, yr_predict1))
# Out:
# [[495  76]
#  [ 16 568]]

# %% [markdown]
# ##Pickling

# %%
import pickle

# %%
filename = 'model.sav'

# %%
pickle.dump(model_rf_smote, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
model_score_r1 = load_model.score(xr_test1, yr_test1)

# %%
model_score_r1
# Out:
# 0.9203463203463204

# %%
# !git clone https://github.com/NoorFatima01/churn-prediction.git
# Out:
# Cloning into 'churn-prediction'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !mv ./churn-model.ipynb /churn-prediction/
# Out:
# mv: cannot stat './churn-model.ipynb': No such file or directory

# %%
# !ls
# Out:
# churn-prediction  model.sav  sample_data  tel_churn.csv

# %%
# !mv /content/churn-model.ipynb /content/churn-prediction/
# Out:
# mv: cannot stat '/content/churn-model.ipynb': No such file or directory
